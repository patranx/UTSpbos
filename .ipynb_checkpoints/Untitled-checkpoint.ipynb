# %%
print("hello world")
print ("Phyton itu mudah banget")
nama = "Adi Saputra"
print (nama)
# Out:
# hello world
# Phyton itu mudah banget
# Adi Saputra

# %%
nama = "Adi Saputra"

jenis_kelamin = "L"
alamat = """
        Jalan Khatulistiwa
        Gang Beringin 1 Dalam
        Pontianak, Kalbar
        Indonesia"""
agama = "Islam"

print(nama)
print(jenis_kelamin)
print(alamat)
print(agama)
# Out:
# Adi Saputra
# L
#
#         Jalan Khatulistiwa
#         Gang Beringin 1 Dalam
#         Pontianak, Kalbar
#         Indonesia
# Islam

# %%
nama = "Adi Saputra"
alamat = "Pontianak, Indonesia"
umur = 20
tinggi = 161
menikah =False

print("Nama   : ", nama)
print("Alamat : ", alamat)
print("Umur   : ", umur)
print("Tinggi : ", tinggi)
if(menikah):
    print("Status : Menikah")
else:
    print("Status : Belum Menikah")
# Out:
#   File "<ipython-input-4-624dac365dd0>", line 13
#     else
#         ^
# SyntaxError: invalid syntax
